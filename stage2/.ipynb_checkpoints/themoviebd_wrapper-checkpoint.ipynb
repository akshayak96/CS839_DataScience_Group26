# %%
from bs4 import BeautifulSoup
from requests import get
import pandas as pd
from time import sleep
from random import randint
from tqdm import tqdm

movies_whole = pd.DataFrame({'Title' : [], 'Date_of_Release' : [], 'Rating' : [], 'Description' : []})

# Redeclaring the lists to store data in
titles = []   # titles of the movies
dates = []    # dates that the movies are released 
ratings = []  # the rating of each movie (% percent)
descriptions = []    # the description of the movies
requests = 0

# form the pages keys
pages = [str(i) for i in range(1,356)]
headers = {"Accept-Language": "en-US, en;q=0.5"}
# For every page in the interval 1-356
for page in tqdm(pages):

    # Make a get request
    response = get('https://www.themoviedb.org/movie/top-rated?language=en-US&page=' + page, headers = headers)
   
    # Pause the loop
    sleep(randint(8,15))

    # Monitor the requests
    requests += 1

    # Parse the content of the request with BeautifulSoup
    html_soup = BeautifulSoup(response.text, 'html.parser')

    # Select all the 50 movie containers from a single page
    mv_containers = html_soup.find_all('div',attrs={"class": 'item poster card'})
    i = 1
    
    # Redeclaring the lists to store data in
    titles = []   # titles of the movies
    dates = []    # dates that the movies are released 
    ratings = []  # the rating of each movie (% percent)
    descriptions = []    # the description of the movies
    print('Page Number:', page)
    # For every movie of these 20
    for container in tqdm(mv_containers):
        
        # Scrape the title
        title = container.find('div', class_ = 'flex').a.text
        titles.append(title)
        
        # Scrape the date
        date = container.find('div', class_ = 'flex').span.text
        dates.append(date)
       
        # Scrape the description
        description = container.find('p', class_ = 'overview').text
        descriptions.append(description)
        
        # Scrape the rating
        rating = container.find('div', class_ = 'percent').span['class'][1].replace('icon-r', '')
        ratings.append(int(rating))
        i+=1

    movies_container = pd.DataFrame({'Title': titles,
                              'Date_of_Release': dates,
                              'Rating': ratings,
                              'Description': descriptions})
        
    movies_whole = movies_whole.append(movies_container, ignore_index=True)
print(movies_whole)
movies_whole.to_csv('tableA.csv', sep=',')
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:13<00:13, 13.39s/it]/s]
# Page Number: 1
#                                             Title     Date_of_Release  Rating  \
# 0                     Dilwale Dulhania Le Jayenge    October 20, 1995    90.0
# 1                        The Shawshank Redemption  September 23, 1994    87.0
# 2                                   The Godfather      March 15, 1972    86.0
# 3                                      Your Name.      April  7, 2017    86.0
# 4                                Schindler's List   December 15, 1993    85.0
# 5                          The Godfather: Part II   December 20, 1974    85.0
# 6                                   Spirited Away  September 20, 2002    85.0
# 7               Spider-Man: Into the Spider-Verse   December 14, 2018    85.0
# 8                                  The Green Mile   December 10, 1999    84.0
# 9                               Life Is Beautiful    October 22, 1998    84.0
# 10                                   Pulp Fiction    October 14, 1994    84.0
# 11                                   A Dog's Will  September 15, 2000    84.0
# 12                                The Dark Knight       July 18, 2008    84.0
# 13                                     Fight Club    October 15, 1999    84.0
# 28                              The Great Dictator    October 15, 1940
# 29                                     City Lights      March  7, 1931
# 30                     Sherlock: The Final Problem    January 15, 2017
# 31                                   Seven Samurai   November 19, 1956
# 32                                      Twin Peaks   December 31, 1989
# 33                                     City of God     August 31, 2002
# 34                              American History X    October 30, 1998
# 35                                Sunset Boulevard     August 10, 1950
# 36                            Howl's Moving Castle       June 10, 2005
# 37               Doctor Who: The Day of the Doctor   November 23, 2013
# 38                         The Empire Strikes Back        May 21, 1980
# 39                               Princess Mononoke    October 29, 1999
#
#     Rating                                        Description
# 0     90.0  Raj is a rich, carefree, happy-go-lucky second...
# 1     87.0  Framed in the 1940s for the double murder of h...
# 2     86.0  Spanning the years 1945 to 1955, a chronicle o...
# 3     86.0  High schoolers Mitsuha and Taki are complete s...
# 4     85.0  The true story of how businessman Oskar Schind...
# 5     85.0  In the continuing saga of the Corleone crime f...
# 6     85.0  A young girl, Chihiro, becomes trapped in a st...
# 7     85.0  Miles Morales is juggling his life between bei...
# 8     84.0  A supernatural tale set on death row in a Sout...
# 9     84.0  A touching story of an Italian book seller of ...
# 10    84.0  A burger-loving hit man, his philosophical par...
# 11    84.0  The lively João Grilo and the sly Chicó are po...
# 12    84.0  Batman raises the stakes in his war on crime. ...
# 13    84.0  A ticking-time-bomb insomniac and a slippery s...
# 14    84.0  When larcenous real estate clerk Marion Crane ...
# 15    84.0  A man with a low IQ has accomplished great thi...
# 16    84.0  Zain, a 12-year-old boy scrambling to survive ...
# 17    84.0  Aragorn is revealed as the heir to the ancient...
# 18    84.0  The defense and the prosecution have rested an...
# 19    84.0  In the final months of World War II, 14-year-o...
# 20    84.0  The true story of Henry Hill, a half-Irish, ha...
# 21    84.0  While serving time for insanity at a state men...
# 22    84.0  A former Prohibition-era Jewish gangster retur...
# 23    84.0  A filmmaker recalls his childhood, when he fel...
# 24    84.0  Aging samurai Hanshiro Tsugumo arrives at the ...
# 25    84.0  Under the direction of a ruthless instructor, ...
# 26    84.0  The second of two theatrically released follow...
# 27    84.0  While the Civil War rages between the Union an...
# 28    84.0  Dictator Adenoid Hynkel tries to expand his em...
# 29    84.0  City Lights is the first silent film that Char...
# 30    84.0  Long buried secrets finally come to light as s...
# 31    84.0  A samurai answers a village's request for prot...
# 32    84.0  Standalone version of the series pilot with an...
# 33    84.0  Cidade de Deus is a shantytown that started du...
# 34    84.0  Derek Vineyard is paroled after serving 3 year...
# 35    84.0  A hack screenwriter writes a screenplay for a ...
# 36    83.0  When Sophie, a shy young woman, is cursed with...
# 37    83.0  In 2013, something terrible is awakening in Lo...
# 38    83.0  The epic saga continues as Luke Skywalker, in ...
# 39    83.0  Ashitaka, a prince of the disappearing Ainu tr...
